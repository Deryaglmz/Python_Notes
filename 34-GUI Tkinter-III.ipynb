# %% [markdown]
# # GUI Tkinter

# %%
from tkinter import *
from tkcalendar import DateEntry


#pack
#place
#grid

master= Tk()

canvas = Canvas(master, height=450, width = 750)
canvas.pack()

frame_top = Frame(master, bg='#add8e6')
frame_top.place(relx=0.1, rely=0.1, relwidth=0.8, relheight=0.1)

frame_bottom_left= Frame(master, bg='#add8e6')
frame_bottom_left.place(relx=0.1, rely=0.21, relwidth=0.23, relheight=0.5)

frame_lower_right= Frame(master, bg='#add8e6')
frame_lower_right.place(relx=0.34, rely=0.21, relwidth=0.56, relheight=0.5)

reminder_type_label = Label(frame_top,  bg='#add8e6', text ="Reminder Type:", font ="Verdana 12 bold")
reminder_type_label.pack(padx=10, pady=10,side= LEFT)

reminder_type_option= StringVar(frame_top)
reminder_type_option.set("\t")

reminder_type_dropdown_menu= OptionMenu(
  frame_top,
  reminder_type_option,
  " My Birthday",
  "Shopping",
  "Payment")
reminder_type_dropdown_menu.pack(padx=10, pady=10,side= LEFT)

reminder_date_picker=DateEntry(frame_top, width = 12, background ="dark blue", foregroud="black", borderwidth=1,locale="de_DE")
reminder_date_picker._top_cal.overrideredirect(False)
reminder_date_picker.pack(padx=10, pady=10,side= RIGHT)

reminder_date_label = Label(frame_top,  bg='#add8e6', text ="Reminder Date:", font ="Verdana 12 bold")
reminder_date_label.pack(padx=10, pady=10,side= RIGHT)

Label(frame_bottom_left, text = "Reminder Method", bg='#add8e6', font ="Verdana 12 bold").pack(padx=10, pady=10,anchor= NW)

var = IntVar()

R1= Radiobutton(frame_bottom_left, text ="Save To System", variable= var, value = 1, bg='#add8e6',font="Verdana 12 bold")
R1.pack(padx=15 ,pady=5, anchor=NW)

R2= Radiobutton(frame_bottom_left, text ="Send An Email", variable= var, value = 1, bg='#add8e6',font="Verdana 12 bold")
R2.pack(padx=15 ,pady=5, anchor=NW)

var1 = IntVar()
C1= Checkbutton(frame_bottom_left, text ="1 Week Ago", variable= var1, onvalue = 1, bg='#add8e6',font="Verdana 12 bold")
C1.pack(padx=20 ,pady=2, anchor=NW)

var2 = IntVar()
C2= Checkbutton(frame_bottom_left, text ="One Day Before", variable= var2, onvalue = 1, bg='#add8e6',font="Verdana 12 bold")
C2.pack(padx=20 ,pady=2, anchor=NW)

var3 = IntVar()
C3= Checkbutton(frame_bottom_left, text ="The Same Day", variable= var3, onvalue = 1, bg='#add8e6',font="Verdana 12 bold")
C3.pack(padx=20 ,pady=2, anchor=NW)

def send():
    pass
    return

Label(frame_lower_right, text = "Reminder Message", bg='#add8e6', font ="Verdana 10 bold").pack(padx=10, pady=10,anchor= NW)

text_field= Text(frame_lower_right, height=9, width=50)
text_field.tag_configure('style', foreground= '#bfbfbf', font= ('Verdana', 7 ,'bold'))
text_field.pack()

welcome_text= "Enter Your Message Here..."
text_field.insert(END, welcome_text, 'style' )

submit_button= Button(frame_lower_right, text='Sumbit', command= master.destroy)
submit_button.pack(anchor=S)

master.mainloop()
